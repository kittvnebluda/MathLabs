# %%
link = "/home/kit/PycharmProjects/MathLabs/digital_culture/task3.1_723814.xlsx"

# %%
import pandas as pd
# !pip install openpyxl
answers = pd.read_excel(link)
# Out:
# Requirement already satisfied: openpyxl in /home/kit/PycharmProjects/MathLabs/venv/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/kit/PycharmProjects/MathLabs/venv/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/home/kit/PycharmProjects/MathLabs/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Посмотрим на наши данные

# %%
answers
# Out:
#                 Choice_1                          Choice_2  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3         Анализ текстов                               NaN
# 4      Машинное обучение               Визуализация данных
# ..                   ...                               ...
# 594    Машинное обучение  Методы искусственного интеллекта
# 595  Визуализация данных             Обработка изображений
# 596                  NaN                               NaN
# 597  Визуализация данных                               NaN
# 598             Big Data               Электронные таблицы
#
#                 Choice_3                          Choice_4           Choice_5  \
# 0                    NaN                               NaN                NaN
# 1                    NaN                               NaN                NaN
# 2                    NaN                               NaN                NaN
# 3                    NaN                               NaN                NaN
# 4    Электронные таблицы  Методы искусственного интеллекта                NaN
# ..                   ...                               ...                ...
# 594             Big Data               Визуализация данных                NaN
# 595  Электронные таблицы                        Статистика  Машинное обучение
# 596                  NaN                               NaN                NaN
# 597                  NaN                               NaN                NaN
# 598                  NaN                               NaN                NaN
#
#     Choice_6 Choice_7 Choice_8 Choice_9
# 0        NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...
# 594      NaN      NaN      NaN      NaN
# 595      NaN      NaN      NaN      NaN
# 596      NaN      NaN      NaN      NaN
# 597      NaN      NaN      NaN      NaN
# 598      NaN      NaN      NaN      NaN
#
# [599 rows x 9 columns]

# %% [markdown]
# Будем действовать по шагам. Вытащим нужную колонку

# %%
answers[['Choice_1']]
# Out:
#                 Choice_1
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3         Анализ текстов
# 4      Машинное обучение
# ..                   ...
# 594    Машинное обучение
# 595  Визуализация данных
# 596                  NaN
# 597  Визуализация данных
# 598             Big Data
#
# [599 rows x 1 columns]

# %% [markdown]
# Теперь вычислим количество уникальных значений вхождения каждого из вариантов ответов

# %%
answers['Choice_1'].value_counts()
# Out:
# Статистика                          76
# Визуализация данных                 74
# Методы искусственного интеллекта    56
# Big Data                            52
# Электронные таблицы                 48
# Python                              44
# Обработка изображений               43
# Машинное обучение                   42
# Анализ текстов                      41
# Ничего из перечисленного            17
# Name: Choice_1, dtype: int64

# %% [markdown]
# Сформируем интересущий нас набор данных

# %%
to_plot = pd.DataFrame(answers['Choice_1'].value_counts())
to_plot
# Out:
#                                   Choice_1
# Статистика                              76
# Визуализация данных                     74
# Методы искусственного интеллекта        56
# Big Data                                52
# Электронные таблицы                     48
# Python                                  44
# Обработка изображений                   43
# Машинное обучение                       42
# Анализ текстов                          41
# Ничего из перечисленного                17

# %% [markdown]
# Назовем полученную колонку именем Amount, отсортируем данные по убыванию ключа

# %%
to_plot.columns = ['Amount']
to_plot = to_plot.sort_index()
to_plot
# Out:
#                                   Amount
# Big Data                              52
# Python                                44
# Анализ текстов                        41
# Визуализация данных                   74
# Машинное обучение                     42
# Методы искусственного интеллекта      56
# Ничего из перечисленного              17
# Обработка изображений                 43
# Статистика                            76
# Электронные таблицы                   48

# %% [markdown]
# Теперь построим столбчатую диаграмму:

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(to_plot.index, to_plot['Amount'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Можно изменить порядок объектов, чтобы он в точности совпадал с тем, что просят в задании

# %%
vertical_stack = pd.concat([to_plot.iloc[2:], to_plot.iloc[:2]], axis=0)
vertical_stack
# Out:
#                                   Amount
# Анализ текстов                        41
# Визуализация данных                   74
# Машинное обучение                     42
# Методы искусственного интеллекта      56
# Ничего из перечисленного              17
# Обработка изображений                 43
# Статистика                            76
# Электронные таблицы                   48
# Big Data                              52
# Python                                44

# %% [markdown]
# И построить саму диаграмму

# %%
plt.bar(vertical_stack.index, vertical_stack['Amount'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# С форматированием индексов можно работать

# %%
vertical_stack.index
# Out:
# Index(['Анализ текстов', 'Визуализация данных', 'Машинное обучение',
#        'Методы искусственного интеллекта', 'Ничего из перечисленного',
#        'Обработка изображений', 'Статистика', 'Электронные таблицы',
#        'Big Data', 'Python'],
#       dtype='object')

# %%
vertical_stack.index = ['Анализ\n текстов', 'Визуализация данных', 'Машинное обучение',
       'Методы искусственного\n интеллекта', 'Ничего из перечисленного',
       'Обработка изображений', 'Статистика', 'Электронные таблицы',
       'Big Data', 'Python']

# %%
plt.bar(vertical_stack.index, vertical_stack['Amount'])
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# Обратимся ко второй части задания. Сначала сведем задачу к предыдущей — распрямим наш набор данных, а затем повторим все то, что уже делали ранее.

# %%
answers
# Out:
#                 Choice_1                          Choice_2  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3         Анализ текстов                               NaN
# 4      Машинное обучение               Визуализация данных
# ..                   ...                               ...
# 594    Машинное обучение  Методы искусственного интеллекта
# 595  Визуализация данных             Обработка изображений
# 596                  NaN                               NaN
# 597  Визуализация данных                               NaN
# 598             Big Data               Электронные таблицы
#
#                 Choice_3                          Choice_4           Choice_5  \
# 0                    NaN                               NaN                NaN
# 1                    NaN                               NaN                NaN
# 2                    NaN                               NaN                NaN
# 3                    NaN                               NaN                NaN
# 4    Электронные таблицы  Методы искусственного интеллекта                NaN
# ..                   ...                               ...                ...
# 594             Big Data               Визуализация данных                NaN
# 595  Электронные таблицы                        Статистика  Машинное обучение
# 596                  NaN                               NaN                NaN
# 597                  NaN                               NaN                NaN
# 598                  NaN                               NaN                NaN
#
#     Choice_6 Choice_7 Choice_8 Choice_9
# 0        NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...
# 594      NaN      NaN      NaN      NaN
# 595      NaN      NaN      NaN      NaN
# 596      NaN      NaN      NaN      NaN
# 597      NaN      NaN      NaN      NaN
# 598      NaN      NaN      NaN      NaN
#
# [599 rows x 9 columns]

# %%
answers.values
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        ['Визуализация данных', nan, nan, ..., nan, nan, nan],
#        ['Big Data', 'Электронные таблицы', nan, ..., nan, nan, nan]],
#       dtype=object)

# %%
answers.values.shape
# Out:
# (599, 9)

# %% [markdown]
# [Гайд](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html) по функции `reshape()`

# %%
answers.values.reshape(-1)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], dtype=object)

# %%
pd.DataFrame(answers.values.reshape(-1))
# Out:
#         0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 5386  NaN
# 5387  NaN
# 5388  NaN
# 5389  NaN
# 5390  NaN
#
# [5391 rows x 1 columns]

# %%
pd.DataFrame(answers.values.reshape(-1))[0]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 5386    NaN
# 5387    NaN
# 5388    NaN
# 5389    NaN
# 5390    NaN
# Name: 0, Length: 5391, dtype: object

# %%
pd.DataFrame(answers.values.reshape(-1))[0].value_counts()
# Out:
# Визуализация данных                 322
# Статистика                          270
# Методы искусственного интеллекта    235
# Электронные таблицы                 234
# Python                              232
# Машинное обучение                   221
# Big Data                            219
# Анализ текстов                      201
# Обработка изображений               193
# Ничего из перечисленного             17
# Name: 0, dtype: int64

# %%
full_to_plot = pd.DataFrame(pd.DataFrame(answers.values.reshape(-1))[0].value_counts())
full_to_plot.columns = ['Amount']
full_to_plot = full_to_plot.sort_index()
full_to_plot
# Out:
#                                   Amount
# Big Data                             219
# Python                               232
# Анализ текстов                       201
# Визуализация данных                  322
# Машинное обучение                    221
# Методы искусственного интеллекта     235
# Ничего из перечисленного              17
# Обработка изображений                193
# Статистика                           270
# Электронные таблицы                  234

# %% [markdown]
# Теперь построим круговую диаграмму

# %%
plt.pie(full_to_plot['Amount'], labels=full_to_plot.index, autopct='%0.1f%%')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (16,16)

plt.subplot(1, 2, 1)  

plt.title('FIRST PLOT')
plt.pie(full_to_plot['Amount'], labels=full_to_plot.index, autopct='%0.2f%%')

plt.subplot(1, 2, 2)
plt.title('SECOND PLOT')
plt.pie(full_to_plot['Amount'], labels=full_to_plot.index, autopct='%0.0f%%', rotatelabels=True)

plt.tight_layout()

plt.show()
